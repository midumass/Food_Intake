# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
food = pd.read_csv('./food_intake.csv')

# %%
food.head(3)
# Out:
#    Year     Butter  Margarine       Lard  Edible beef tallow  Shortening  \
# 0  1970  29.022038  58.637680  16.267078                 NaN   99.621004
# 1  1971  27.833619  58.561263  14.730700                 NaN   96.502563
# 2  1972  26.781362  59.334722  12.549491                 NaN  101.193695
#
#    Salad and cooking oils  Other edible fats and oils  Added fats and oils  \
# 0              115.495103                   18.328534           337.371437
# 1              117.222108                   18.328534           333.178787
# 2              126.333511                   18.328534           344.521315
#
#    Light cream  ...  Percentage of daily total Caloric sweeteners  \
# 0     0.622809  ...                                     16.186725
# 1     0.541508  ...                                     16.323053
# 2     0.479240  ...                                     16.488486
#
#    Percentage of daily total Total  \
# 0                            100.0
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x = food['Year'], \
                         y = food['Daily caloric total from Meat, eggs, and nuts'], \
                         mode = 'lines', \
                         name = 'Meat, eggs and nuts'))

fig.add_trace(go.Scatter(x = food['Year'], \
                         y = food['Daily caloric total from Dairy'], \
                         mode = 'lines', \
                         name = 'Dairy'))

fig.add_trace(go.Scatter(x = food['Year'], \
                         y = food['Daily caloric total from Fruit'], \
                         mode = 'lines', \
                         name = 'Fruit'))

fig.add_trace(go.Scatter(x = food['Year'], \
                         y = food['Daily caloric total from Vegetables'], \
                         mode = 'lines', \
                         name = 'Vegetables'))

fig.add_trace(go.Scatter(x = food['Year'], \
                         y = food['Daily caloric total from Flour and cereal products'], \
                         mode = 'lines', \
                         name = 'Grains'))

fig.add_trace(go.Scatter(x = food['Year'], \
                         y = food['Daily caloric total from Added fats and oils and dairy fats'], \
                         mode = 'lines', \
                         name = 'Added Fats'))

fig.add_trace(go.Scatter(x = food['Year'], \
                         y = food['Daily caloric total from Sugar and sweeteners (Added)'], \
                         mode = 'lines', \
                         name = 'Sweeteners'))

fig.update_layout(title_text = 'Total Caloric Consumption of Major Food Groups')

fig.show()
# Out:
# <div>
#
#
#             <div id="48b784eb-7bb0-4f85-a959-7bd611302aec" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("48b784eb-7bb0-4f85-a959-7bd611302aec")) {
#                     Plotly.newPlot(
#                         '48b784eb-7bb0-4f85-a959-7bd611302aec',
# ...

# %%
grains = food[['Year',\
               'White and whole wheat',\
               'Durum flour',\
               'Wheat flour',\
               'Rye flour',\
               'Rice',\
               'Corn Flour and meal',\
               'Hominy and grits',\
               'Cornstarch',\
               'Corn products',\
               'Oat products',\
               'Barley products',\
               'Flour and cereal products']]

# %%
sorted(grains.columns)
# Out:
# ['Barley products',
#  'Corn Flour and meal',
#  'Corn products',
#  'Cornstarch',
#  'Durum flour',
#  'Flour and cereal products',
#  'Hominy and grits',
#  'Oat products',
#  'Rice',
#  'Rye flour',
#  'Wheat flour',
#  'White and whole wheat',
#  'Year']

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x = grains['Year'], \
                         y = grains['Barley products'], \
                         mode = 'lines', \
                         name = 'Barley products'))

fig.add_trace(go.Scatter(x = grains['Year'], \
                         y = grains['Corn products'], \
                         mode = 'lines', \
                         name = 'Corn products'))

fig.add_trace(go.Scatter(x = grains['Year'], \
                         y = grains['Rye flour'], \
                         mode = 'lines', \
                         name = 'Rye products'))

fig.add_trace(go.Scatter(x = grains['Year'], \
                         y = grains['Wheat flour'], \
                         mode = 'lines', \
                         name = 'Wheat products'))

fig.add_trace(go.Scatter(x = grains['Year'], \
                         y = grains['Oat products'], \
                         mode = 'lines', \
                         name = 'Oat products'))

fig.add_trace(go.Scatter(x = grains['Year'], \
                         y = grains['Rice'], \
                         mode = 'lines', \
                         name = 'Rice products'))

fig.update_layout(title_text = 'Total Caloric Consumption of Grains')

fig.show()
# Out:
# <div>
#
#
#             <div id="773a8623-59d4-4fd4-9673-e59c158d9eec" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("773a8623-59d4-4fd4-9673-e59c158d9eec")) {
#                     Plotly.newPlot(
#                         '773a8623-59d4-4fd4-9673-e59c158d9eec',
# ...

# %%
meats = food[['Year',\
              'Beef',\
              'Veal',\
              'Pork',\
              'Lamb',\
              'Chicken',\
              'Turkey',\
              'Fresh and Frozen Fish',\
              'Fresh and Frozen Shellfish',\
              'Canned Total',\
              'Fish and shellfish',\
              'Cured']]

# %%
sorted(meats.columns)
# Out:
# ['Beef',
#  'Canned Total',
#  'Chicken',
#  'Cured',
#  'Fish and shellfish',
#  'Fresh and Frozen Fish',
#  'Fresh and Frozen Shellfish',
#  'Lamb',
#  'Pork',
#  'Turkey',
#  'Veal',
#  'Year']

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x = meats['Year'], \
                         y = meats['Beef'], \
                         mode = 'lines', \
                         name = 'Beef'))

fig.add_trace(go.Scatter(x = meats['Year'], \
                         y = meats['Fish and shellfish'], \
                         mode = 'lines', \
                         name = 'Fish and Shellfish'))

fig.add_trace(go.Scatter(x = meats['Year'], \
                         y = meats['Lamb'], \
                         mode = 'lines', \
                         name = 'Lamb'))

fig.add_trace(go.Scatter(x = meats['Year'], \
                         y = meats['Pork'], \
                         mode = 'lines', \
                         name = 'Pork'))

fig.add_trace(go.Scatter(x = meats['Year'], \
                         y = meats['Turkey'], \
                         mode = 'lines', \
                         name = 'Turkey'))

fig.add_trace(go.Scatter(x = meats['Year'], \
                         y = meats['Chicken'], \
                         mode = 'lines', \
                         name = 'Chicken'))

fig.update_layout(title_text = 'Total Caloric Consumption of Meats')

fig.show()
# Out:
# <div>
#
#
#             <div id="544d6eb3-34a7-4d17-8c54-d27344b0ed12" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("544d6eb3-34a7-4d17-8c54-d27344b0ed12")) {
#                     Plotly.newPlot(
#                         '544d6eb3-34a7-4d17-8c54-d27344b0ed12',
# ...

# %%
vegs = food[['Year',\
             'Fresh vegetables',\
             'Canned vegetables',\
             'Frozen vegetables',\
             'Dehydrated vegetables',\
             'Chips and shoestring potatoes',\
             'Dry edible beans',\
             'Dry peas and lentils',\
             'Legumes']]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x = vegs['Year'], \
                         y = vegs['Fresh vegetables'], \
                         mode = 'lines', \
                         name = 'Fresh'))

fig.add_trace(go.Scatter(x = vegs['Year'], \
                         y = vegs['Canned vegetables'], \
                         mode = 'lines', \
                         name = 'Canned'))

fig.add_trace(go.Scatter(x = vegs['Year'], \
                         y = vegs['Frozen vegetables'], \
                         mode = 'lines', \
                         name = 'Frozen'))

fig.add_trace(go.Scatter(x = vegs['Year'], \
                         y = vegs['Dehydrated vegetables'], \
                         mode = 'lines', \
                         name = 'Dehydrated'))

fig.add_trace(go.Scatter(x = vegs['Year'], \
                         y = vegs['Chips and shoestring potatoes'], \
                         mode = 'lines', \
                         name = 'Chips'))

fig.add_trace(go.Scatter(x = vegs['Year'], \
                         y = vegs['Dry edible beans'], \
                         mode = 'lines', \
                         name = 'Dry Beans'))

fig.add_trace(go.Scatter(x = vegs['Year'], \
                         y = vegs['Dry peas and lentils'], \
                         mode = 'lines', \
                         name = 'Peas and Lentils'))

fig.add_trace(go.Scatter(x = vegs['Year'], \
                         y = vegs['Legumes'], \
                         mode = 'lines', \
                         name = 'Legumes'))

fig.update_layout(title_text = 'Total Caloric Consumption of Vegetables')

fig.show()
# Out:
# <div>
#
#
#             <div id="4c03ab0d-4bbe-4472-8ca0-e90c6b0f9c37" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4c03ab0d-4bbe-4472-8ca0-e90c6b0f9c37")) {
#                     Plotly.newPlot(
#                         '4c03ab0d-4bbe-4472-8ca0-e90c6b0f9c37',
# ...

# %%
fresh_vegs = food[['Year',\
             'Fresh vegetables',\
             'Fresh Kale',\
             'Fresh Head lettuce',\
             'Fresh Romaine and leaf lettuce',\
             'Fresh Onions',\
             'Fresh Tomatoes',\
             'Fresh Sweet potatoes',\
             'Fresh Potatoes',\
             'Fresh Bell peppers',\
             'Fresh Cauliflower',\
             'Fresh Broccoli',\
             'Fresh Asparagus',\
             'Fresh Cucumbers',\
             'Fresh Mushrooms']]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Tomatoes'], \
                         mode = 'lines', \
                         name = 'Tomatoes'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Sweet potatoes'], \
                         mode = 'lines', \
                         name = 'Sweet Potatoes'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Romaine and leaf lettuce'], \
                         mode = 'lines', \
                         name = 'Romaine'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Potatoes'], \
                         mode = 'lines', \
                         name = 'Potatoes'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Onions'], \
                         mode = 'lines', \
                         name = 'Onions'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Mushrooms'], \
                         mode = 'lines', \
                         name = 'Mushrooms'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Kale'], \
                         mode = 'lines', \
                         name = 'Kale'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Head lettuce'], \
                         mode = 'lines', \
                         name = 'Iceberg'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Cucumbers'], \
                         mode = 'lines', \
                         name = 'Cucumbers'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Cauliflower'], \
                         mode = 'lines', \
                         name = 'Cauliflower'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Broccoli'], \
                         mode = 'lines', \
                         name = 'Broccoli'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Bell peppers'], \
                         mode = 'lines', \
                         name = 'Bell Peppers'))

fig.add_trace(go.Scatter(x = fresh_vegs['Year'], \
                         y = fresh_vegs['Fresh Asparagus'], \
                         mode = 'lines', \
                         name = 'Asparagus'))

fig.update_layout(title_text = 'Total Caloric Consumption of Fresh Vegetables')

fig.show()
# Out:
# <div>
#
#
#             <div id="fc7da646-dd37-43da-b096-d3a49c1f62be" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fc7da646-dd37-43da-b096-d3a49c1f62be")) {
#                     Plotly.newPlot(
#                         'fc7da646-dd37-43da-b096-d3a49c1f62be',
# ...

# %%
fats = food[['Year',\
             'Butter',\
             'Margarine',\
             'Lard',\
             'Edible beef tallow',\
             'Shortening',\
             'Salad and cooking oils',\
             'Dairy fats']]

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x = fats['Year'], \
                         y = fats['Butter'], \
                         mode = 'lines', \
                         name = 'Butter'))

fig.add_trace(go.Scatter(x = fats['Year'], \
                         y = fats['Margarine'], \
                         mode = 'lines', \
                         name = 'Margarine'))

fig.add_trace(go.Scatter(x = fats['Year'], \
                         y = fats['Lard'], \
                         mode = 'lines', \
                         name = 'Lard'))

fig.add_trace(go.Scatter(x = fats['Year'], \
                         y = fats['Edible beef tallow'], \
                         mode = 'lines', \
                         name = 'Beef Tallow'))

fig.add_trace(go.Scatter(x = fats['Year'], \
                         y = fats['Shortening'], \
                         mode = 'lines', \
                         name = 'Shortening'))

fig.add_trace(go.Scatter(x = fats['Year'], \
                         y = fats['Salad and cooking oils'], \
                         mode = 'lines', \
                         name = 'Vegetable Oils'))

fig.add_trace(go.Scatter(x = fats['Year'], \
                         y = fats['Dairy fats'], \
                         mode = 'lines', \
                         name = 'Dairy Fats'))

fig.update_layout(title_text = 'Total Caloric Consumption of Fats and Oils')

fig.show()
# Out:
# <div>
#
#
#             <div id="86714328-beab-45d4-8a13-a46197f92609" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("86714328-beab-45d4-8a13-a46197f92609")) {
#                     Plotly.newPlot(
#                         '86714328-beab-45d4-8a13-a46197f92609',
# ...
